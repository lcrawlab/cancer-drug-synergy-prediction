# %% [markdown]
# File for Testing Methods Locally Instead of Having to Wait for Oscar

# %%
# import everything you need up here

from modelPCNNGL import *
from pytorchGetData import *
from pytorchUtils import *
from sklearn.model_selection import KFold, train_test_split
import torch

file_path = "scratch/anticancer-synergy-prediction-scratch/"
output_prefix = file_path + "experiments/20240717_pcnnModel_test/"

# %% [markdown]
# # modelPCNNGL.py Tests #

# %% [markdown]
# - test get_pcnngl_hyperparameters

# %%
test_params = get_pcnngl_hyperparameters(1)
params = {
    'num_epochs': 300,
    'batch_size': 128,
    'learning_rate': 0.0002,
    'loss_fxn': 'MSELoss',
    'optimizer': 'Adam',
}
assert test_params == params, print('params error: ' + str(test_params) + ' vs ' + str(params))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))
# Out:
# Using device: cpu

# %% [markdown]
# Get the data and mask

# %%
print("Loading data...")
mfp_bc_fn = 'data/ASP_dataset_slices/all_cancer_256_mfp_bc0_comboscore.csv'
all_cancer_data_fn = get_all_cancer_dataset_filename(True, False, False, False, True, False, False, 256, 0)
breast_cancer_indices = get_cancer_type_indices_filename('breast', True, False, False)

data = MorganFingerprintDataset(mfp_bc_fn, True, breast_cancer_indices)
print("Breast cancer BC balanced # of samples: " + str(len(data)))

print("Getting mask...")
mask_fp = output_prefix + '1mask.csv'
mask = get_mask1gl(True, False, False, False, mask_fp, True, False, 256)
hidden_layer_size = mask.shape[0]

output_plot_path = output_prefix + '_'
print(output_prefix)
# Out:
# Loading data...
# Using filename:  data/ASP_dataset_slices/all_cancer_256_mfp_bc0_comboscore.csv
# Original Dataset shape: (300928, 513)
# Reading indices from data/ASP_dataset_slices/breast_comboscore_indices.txt
# Filtered Dataset shape: (20989, 513)
# Initial dataset size: 20989
# Balancing classes
# Balanced dataset size: 13316
# Breast cancer BC balanced # of samples: 13316
# Getting mask...
# torch.Size([722, 512])
# scratch/anticancer-synergy-prediction-scratch/experiments/20240717_pcnnModel_test/

# %% [markdown]
# - test training the model with k fold cross validation

# %%
lf=nn.MSELoss()
# K fold cross validation
kf = KFold(n_splits=3, shuffle=True)
all_fold_metrics = pd.DataFrame()
all_fold_metrics = pd.DataFrame(columns=['Accuracy', 'Sensitivity', 'Specificity', 'Precision', 'F1 Score', 'MCC', 'AUC', 'Kappa'])

for i, (train_tune_index, test_index) in enumerate(kf.split(data.x)):
    print(f"Fold {i+1}")

    train_index, tune_index = train_test_split(train_tune_index, test_size=0.1)
    train_subset = Subset(data, train_index)
    train_dataloader = DataLoader(train_subset, batch_size=128, shuffle=True)
    tune_subset = Subset(data, tune_index)
    tune_dataloader = DataLoader(tune_subset, batch_size=128, shuffle=True)
    test_subset = Subset(data, test_index)
    test_dataloader = DataLoader(test_subset, batch_size=128, shuffle=True)

    input_size = train_dataloader.dataset[0][0].shape[0]

    # Create the model
    pcnn_gene_layer_model = PCNNGLModel(
        input_size = input_size,
        mask = mask,
        hidden_size = hidden_layer_size,
        num_epochs = 51, # Short for local testing
        learning_rate = params["learning_rate"],
        loss_fxn = lf,
        device = device,
        binary_classification = True,
    )

    optimizer = optim.Adam(pcnn_gene_layer_model.parameters(), lr=params["learning_rate"])

    # Check which device pcnn_gene_layer_model is on
    print("pcnn_gene_layer_model device: " + str(next(pcnn_gene_layer_model.parameters()).device))
    
    output_file_prefix = output_prefix +'hl' + str(hidden_layer_size) + '_ne' \
        + str(params["num_epochs"]) + '_bs'  + str(params["batch_size"]) + '_lr' \
        + str(params["learning_rate"]) + '_lf' + params["loss_fxn"] + '_opt' + params["optimizer"] + '/'
    
    print(output_file_prefix)
    
    if not os.path.exists(output_file_prefix):
        os.makedirs(output_file_prefix)
    
    # Train the model
    train_cov_model(
        pcnn_gene_layer_model,
        train_dataloader,
        optimizer,
        output_file_prefix,
        tune_dataloader=tune_dataloader,
        loss_file=output_file_prefix,
    )
    # Print last training loss
    print("Last training loss: " + str(pcnn_gene_layer_model.train_loss_over_time[-1]))

    print_model_params(pcnn_gene_layer_model)

    # Test the model
    fold_metrics = test_cov_model(pcnn_gene_layer_model, test_dataloader, output_file_prefix)
    all_fold_metrics.loc[i] = fold_metrics

all_fold_metrics.to_csv(output_prefix + 'all_fold_metrics.csv')
print(all_fold_metrics.mean())
# Out:
# Fold 1
# Actually using BCE Loss
# pcnn_gene_layer_model device: cpu
# scratch/anticancer-synergy-prediction-scratch/experiments/20240717_pcnnModel_test/hl722_ne300_bs128_lr0.0002_lfMSELoss_optAdam/
# Model is training
# Layer: input.weight, Size: torch.Size([722, 512])
# Layer: input.bias, Size: torch.Size([722])
# Layer: output.weight, Size: torch.Size([1, 722])
# Layer: output.bias, Size: torch.Size([1])
# Layer: batch_norms.0.weight, Size: torch.Size([512])
# Layer: batch_norms.0.bias, Size: torch.Size([512])
# Layer: batch_norms.0.running_mean, Size: torch.Size([512])
# Layer: batch_norms.0.running_var, Size: torch.Size([512])
# Layer: batch_norms.0.num_batches_tracked, Size: torch.Size([])
# Layer: batch_norms.1.weight, Size: torch.Size([722])
# Layer: batch_norms.1.bias, Size: torch.Size([722])
# Layer: batch_norms.1.running_mean, Size: torch.Size([722])
# Layer: batch_norms.1.running_var, Size: torch.Size([722])
# Layer: batch_norms.1.num_batches_tracked, Size: torch.Size([])
# Epoch [0/51], Loss: 0.7233, Accuracy: 50.49%
# Epoch [0/51], Tune Loss: 0.6976, Tune Accuracy: 55.29%
# Epoch [25/51], Loss: 0.6069, Accuracy: 66.60%
# Epoch [25/51], Tune Loss: 0.6471, Tune Accuracy: 61.60%
# Epoch [50/51], Loss: 0.5889, Accuracy: 68.51%
# Epoch [50/51], Tune Loss: 0.6478, Tune Accuracy: 61.26%
# Last training loss: 0.5888942612542046
# +----------------------+----------------------+
# |       Modules        | Trainable Parameters |
# +----------------------+----------------------+
# |     input.weight     |        369664        |
# |      input.bias      |         722          |
# |    output.weight     |         722          |
# |     output.bias      |          1           |
# | batch_norms.0.weight |         512          |
# |  batch_norms.0.bias  |         512          |
# | batch_norms.1.weight |         722          |
# |  batch_norms.1.bias  |         722          |
# |        Total         |        373577        |
# +----------------------+----------------------+
# Total number of all parameters: 373577
# Model is testing
# Y test shape: (4439, 1)
# Y pred shape: (4439, 1)
# Fold 2
# Actually using BCE Loss
# pcnn_gene_layer_model device: cpu
# scratch/anticancer-synergy-prediction-scratch/experiments/20240717_pcnnModel_test/hl722_ne300_bs128_lr0.0002_lfMSELoss_optAdam/
# Model is training
# Layer: input.weight, Size: torch.Size([722, 512])
# Layer: input.bias, Size: torch.Size([722])
# Layer: output.weight, Size: torch.Size([1, 722])
# Layer: output.bias, Size: torch.Size([1])
# Layer: batch_norms.0.weight, Size: torch.Size([512])
# Layer: batch_norms.0.bias, Size: torch.Size([512])
# Layer: batch_norms.0.running_mean, Size: torch.Size([512])
# Layer: batch_norms.0.running_var, Size: torch.Size([512])
# Layer: batch_norms.0.num_batches_tracked, Size: torch.Size([])
# Layer: batch_norms.1.weight, Size: torch.Size([722])
# Layer: batch_norms.1.bias, Size: torch.Size([722])
# Layer: batch_norms.1.running_mean, Size: torch.Size([722])
# Layer: batch_norms.1.running_var, Size: torch.Size([722])
# Layer: batch_norms.1.num_batches_tracked, Size: torch.Size([])
# Epoch [0/51], Loss: 0.7188, Accuracy: 51.32%
# Epoch [0/51], Tune Loss: 0.7021, Tune Accuracy: 54.73%
# Epoch [25/51], Loss: 0.6067, Accuracy: 67.09%
# Epoch [25/51], Tune Loss: 0.6694, Tune Accuracy: 59.23%
# Epoch [50/51], Loss: 0.5923, Accuracy: 68.24%
# Epoch [50/51], Tune Loss: 0.6723, Tune Accuracy: 59.68%
# Last training loss: 0.5923093765500992
# +----------------------+----------------------+
# |       Modules        | Trainable Parameters |
# +----------------------+----------------------+
# |     input.weight     |        369664        |
# |      input.bias      |         722          |
# |    output.weight     |         722          |
# |     output.bias      |          1           |
# | batch_norms.0.weight |         512          |
# |  batch_norms.0.bias  |         512          |
# | batch_norms.1.weight |         722          |
# |  batch_norms.1.bias  |         722          |
# |        Total         |        373577        |
# +----------------------+----------------------+
# Total number of all parameters: 373577
# Model is testing
# Y test shape: (4439, 1)
# Y pred shape: (4439, 1)
# Fold 3
# Actually using BCE Loss
# pcnn_gene_layer_model device: cpu
# scratch/anticancer-synergy-prediction-scratch/experiments/20240717_pcnnModel_test/hl722_ne300_bs128_lr0.0002_lfMSELoss_optAdam/
# Model is training
# Layer: input.weight, Size: torch.Size([722, 512])
# Layer: input.bias, Size: torch.Size([722])
# Layer: output.weight, Size: torch.Size([1, 722])
# Layer: output.bias, Size: torch.Size([1])
# Layer: batch_norms.0.weight, Size: torch.Size([512])
# Layer: batch_norms.0.bias, Size: torch.Size([512])
# Layer: batch_norms.0.running_mean, Size: torch.Size([512])
# Layer: batch_norms.0.running_var, Size: torch.Size([512])
# Layer: batch_norms.0.num_batches_tracked, Size: torch.Size([])
# Layer: batch_norms.1.weight, Size: torch.Size([722])
# Layer: batch_norms.1.bias, Size: torch.Size([722])
# Layer: batch_norms.1.running_mean, Size: torch.Size([722])
# Layer: batch_norms.1.running_var, Size: torch.Size([722])
# Layer: batch_norms.1.num_batches_tracked, Size: torch.Size([])
# Epoch [0/51], Loss: 0.7151, Accuracy: 51.15%
# Epoch [0/51], Tune Loss: 0.6765, Tune Accuracy: 57.09%
# Epoch [25/51], Loss: 0.6150, Accuracy: 66.61%
# Epoch [25/51], Tune Loss: 0.6392, Tune Accuracy: 64.53%
# Epoch [50/51], Loss: 0.5967, Accuracy: 67.95%
# Epoch [50/51], Tune Loss: 0.6440, Tune Accuracy: 64.64%
# Last training loss: 0.5967275169160631
# +----------------------+----------------------+
# |       Modules        | Trainable Parameters |
# +----------------------+----------------------+
# |     input.weight     |        369664        |
# |      input.bias      |         722          |
# |    output.weight     |         722          |
# |     output.bias      |          1           |
# | batch_norms.0.weight |         512          |
# |  batch_norms.0.bias  |         512          |
# | batch_norms.1.weight |         722          |
# |  batch_norms.1.bias  |         722          |
# |        Total         |        373577        |
# +----------------------+----------------------+
# Total number of all parameters: 373577
# Model is testing
# Y test shape: (4438, 1)
# Y pred shape: (4438, 1)
# Accuracy       0.629093
# Sensitivity    0.610334
# Specificity    0.647787
# Precision      0.634042
# F1 Score       0.621961
# MCC            0.258302
# AUC            0.629060
# Kappa          0.258121
# dtype: float64

# %% [markdown]
# Test training the covariate model for additional set of epochs (the loading code)

# %%
weights_fp = output_prefix + "hl722_ne300_bs128_lr0.0002_lfMSELoss_optAdam/checkpoint/wts_trep50.pth"
loss_fp = output_prefix + "hl722_ne300_bs128_lr0.0002_lfMSELoss_optAdam/checkpoint/loss_trep50.pkl"

# Train the model for 5 more epochs
pcnn_gene_layer_model.num_epochs = 10
train_cov_model(
    pcnn_gene_layer_model,
    train_dataloader,
    optimizer,
    output_prefix,
    tune_dataloader=tune_dataloader,
    checkpoint_weights=weights_fp,
    loss_file=loss_fp,
)
# Out:
# Model is training
# Weights loaded from file
# Loss loaded from file
# Training for 10 more epochs
# Layer: input.weight, Size: torch.Size([722, 512])
# Layer: input.bias, Size: torch.Size([722])
# Layer: output.weight, Size: torch.Size([1, 722])
# Layer: output.bias, Size: torch.Size([1])
# Layer: batch_norms.0.weight, Size: torch.Size([512])
# Layer: batch_norms.0.bias, Size: torch.Size([512])
# Layer: batch_norms.0.running_mean, Size: torch.Size([512])
# Layer: batch_norms.0.running_var, Size: torch.Size([512])
# Layer: batch_norms.0.num_batches_tracked, Size: torch.Size([])
# Layer: batch_norms.1.weight, Size: torch.Size([722])
# Layer: batch_norms.1.bias, Size: torch.Size([722])
# Layer: batch_norms.1.running_mean, Size: torch.Size([722])
# Layer: batch_norms.1.running_var, Size: torch.Size([722])
# Layer: batch_norms.1.num_batches_tracked, Size: torch.Size([])
# Epoch [0/10], Loss: 0.5973, Accuracy: 68.04%
# Epoch [0/10], Tune Loss: 0.6431, Tune Accuracy: 64.98%
# PCNNGLModel(
#   (loss_fxn): BCELoss()
#   (sigmoid): Sigmoid()
#   (input): Linear(in_features=512, out_features=722, bias=True)
#   (output): Linear(in_features=722, out_features=1, bias=True)
#   (batch_norms): ModuleList(
#     (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(722, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (ReLU): ReLU()
# )
